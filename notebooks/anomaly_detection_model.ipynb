# %%
import pandas as pd
df = pd.read_csv("news_clean.csv")
df.head()
# Out:
#                                              Article        Date  \
# 0  KARACHI: The Sindh government has decided to b...  2015-01-01
# 1  HONG KONG: Asian markets started 2015 on an up...  2015-01-02
# 2  HONG KONG:  Hong Kong shares opened 0.66 perce...  2015-01-05
# 3  HONG KONG: Asian markets tumbled Tuesday follo...  2015-01-06
# 4  NEW YORK: US oil prices Monday slipped below $...  2015-01-06
#
#                                              Heading  NewsType  AH  year  \
# 0  sindh govt decides to cut public transport far...  business NaN  2015
# 1                    asia stocks up in new year trad  business NaN  2015
# 2           hong kong stocks open 0.66 percent lower  business NaN  2015
# 3              asian stocks sink euro near nine year  business NaN  2015
# 4                 us oil prices slip below 50 a barr  business NaN  2015
#
#    month  day  sentiment  emotion  Location  \
# 0      1    1        NaN      NaN       NaN
# 1      1    2        NaN      NaN       NaN
# 2      1    5        NaN      NaN       NaN
# 3      1    6        NaN      NaN       NaN
# 4      1    6        NaN      NaN       NaN
#
#                                        article_clean  \
# 0  karachi the sindh government has decided to br...
# 1  hong kong asian markets started on an upswing ...
# 2  hong kong hong kong shares opened percent lowe...
# 3  hong kong asian markets tumbled tuesday follow...
# 4  new york us oil prices monday slipped below a ...
#
#                                        heading_clean location_reported  \
# 0  sindh govt decides to cut public transport far...           UNKNOWN
# 1                    asia stocks up in new year trad           UNKNOWN
# 2                hong kong stocks open percent lower           UNKNOWN
# 3              asian stocks sink euro near nine year           UNKNOWN
# 4                    us oil prices slip below a barr           UNKNOWN
#
#   location_extracted
# 0            UNKNOWN
# 1               asia
# 2          hong kong
# 3            UNKNOWN
# 4                 us

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

text_corpus = (
    df["heading_clean"].fillna("") + " " +
    df["article_clean"].fillna("")
)

tfidf = TfidfVectorizer(max_features=3000, ngram_range=(1, 2))
X_tfidf = tfidf.fit_transform(text_corpus)

X_tfidf.shape
# Out:
# (2692, 3000)

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(
    n_estimators=200,
    contamination=0.05,
    random_state=42
)

iso.fit(X_tfidf)

df["anomaly_label"] = iso.predict(X_tfidf)
df["anomaly_score"] = -iso.decision_function(X_tfidf)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

text_corpus = (
    df["heading_clean"].fillna("") + " " +
    df["article_clean"].fillna("")
)

tfidf = TfidfVectorizer(max_features=3000, ngram_range=(1, 2))
X_tfidf = tfidf.fit_transform(text_corpus)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

# Boolean mask as NumPy array
mask = df["location_extracted"].ne("UNKNOWN").values

# Filter X and y using the same mask
X_loc = X_tfidf[mask]
y_loc = df.loc[mask, "location_extracted"]

X_train, X_test, y_train, y_test = train_test_split(
    X_loc, y_loc,
    test_size=0.2,
    random_state=42,
    stratify=y_loc
)

clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2587628296.py in <cell line: 0>()
#      11 y_loc = df.loc[mask, "location_extracted"]
#      12
# ---> 13 X_train, X_test, y_train, y_test = train_test_split(
#      14     X_loc, y_loc,
#      15     test_size=0.2,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2870         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2871
# -> 2872         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2873
#    2874     train, test = ensure_common_namespace_device(arrays[0], train, test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#    1907         """
#    1908         X, y, groups = indexable(X, y, groups)
# -> 1909         for train, test in self._iter_indices(X, y, groups):
#    1910             yield train, test
#    1911
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    2316         class_counts = np.bincount(y_indices)
#    2317         if np.min(class_counts) < 2:
# -> 2318             raise ValueError(
#    2319                 "The least populated class in y has only 1"
#    2320                 " member, which is too few. The minimum"
#
# ValueError: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import numpy as np

mask = df["location_extracted"].ne("UNKNOWN").values

X_loc = X_tfidf[mask]
y_loc = df.loc[mask, "location_extracted"]

X_train, X_test, y_train, y_test = train_test_split(
    X_loc, y_loc,
    test_size=0.2,
    random_state=42   # 👈 NO stratify here
)

clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                   precision    recall  f1-score   support
#
#      Afghanistan       0.00      0.00      0.00         1
#             Afri       0.00      0.00      0.00         1
#             Apri       0.00      0.00      0.00         1
# Arcelik Pakistan       0.00      0.00      0.00         1
#        Argentina       0.67      1.00      0.80         2
#             Asia       0.57      0.67      0.62         6
#          Asia Cu       0.00      0.00      0.00         1
#        Australia       0.64      1.00      0.78         9
#       Bangladesh       1.00      0.50      0.67         8
#          Beijing       0.00      0.00      0.00         1
#          Belgium       0.00      0.00      0.00         2
#         Brisbane       0.00      0.00      0.00         1
#          Britain       0.00      0.00      0.00         3
#            Chile       0.00      0.00      0.00         1
#            China       0.67      1.00      0.80         6
#         Colombia       0.00      0.00      0.00         1
#             Copa       0.00      0.00      0.00         1
#          England       0.59      0.87      0.70        23
#          Everest       0.00      0.00      0.00         1
#           France       0.00      0.00      0.00         5
#   France Germany       0.00      0.00      0.00         1
#          Germany       0.00      0.00      0.00         2
#        Hong Kong       0.00      0.00      0.00         2
#            India       0.77      0.81      0.79        21
#     India Ashwin       0.00      0.00      0.00         1
#        Infantino       0.00      0.00      0.00         1
#             Iran       1.00      0.71      0.83         7
#          Ireland       0.00      0.00      0.00         1
#        Islamabad       0.33      0.33      0.33         3
# Islamabad United       0.00      0.00      0.00         2
#            Italy       0.00      0.00      0.00         3
#           Lianna       0.00      0.00      0.00         1
#       Louisville       0.00      0.00      0.00         1
# Mexico Venezuela       0.00      0.00      0.00         1
#           Mobile       0.00      0.00      0.00         1
#             Modi       0.00      0.00      0.00         1
#        N Zealand       0.00      0.00      0.00         1
#               NZ       0.00      0.00      0.00         1
#      New Zealand       0.20      0.20      0.20         5
#          Nigeria       0.00      0.00      0.00         1
#              Nob       0.00      0.00      0.00         1
#       North Asia       0.00      0.00      0.00         1
#             Paki       0.00      0.00      0.00         3
#         Pakistan       0.36      1.00      0.53        44
#           Panama       0.00      0.00      0.00         1
#            Paris       0.00      0.00      0.00         2
#           Poland       0.00      0.00      0.00         1
#          Pollard       0.00      0.00      0.00         1
#         Portugal       0.00      0.00      0.00         1
#         Qadhafis       0.00      0.00      0.00         1
#           Rabada       0.00      0.00      0.00         2
#              SBP       0.00      0.00      0.00         1
#            Sania       0.00      0.00      0.00         1
#           Santos       0.00      0.00      0.00         1
#     Saudi Arabia       0.00      0.00      0.00         1
#            Sindh       0.00      0.00      0.00         1
#         Somerset       0.00      0.00      0.00         1
#       South Afri       0.00      0.00      0.00         1
#     South Africa       1.00      0.75      0.86         8
#            Spain       0.00      0.00      0.00         1
#        Sri Lanka       0.00      0.00      0.00         4
#         Stephens       0.00      0.00      0.00         1
#      Switzerland       0.00      0.00      0.00         1
#           Sydney       0.00      0.00      0.00         1
#            Tokyo       0.83      1.00      0.91         5
#               UK       0.00      0.00      0.00         2
#               US       0.35      0.60      0.44        15
#           Valcke       0.00      0.00      0.00         1
#        Venezuela       0.00      0.00      0.00         1
#      West Indies       0.00      0.00      0.00         4
#            Zalmi       0.00      0.00      0.00         3
#         Zimbabwe       0.00      0.00      0.00         2
#             asia       0.00      0.00      0.00         2
#     asia markets       0.00      0.00      0.00         1
#            china       0.00      0.00      0.00         4
#            dubai       0.00      0.00      0.00         1
#             iran       0.00      0.00      0.00         1
#             paki       0.00      0.00      0.00         2
#         pakistan       0.00      0.00      0.00         5
#         shanghai       0.00      0.00      0.00         2
#            tokyo       0.00      0.00      0.00         3
#               us       0.00      0.00      0.00         1
#          valuati       0.00      0.00      0.00         1
#            yemen       0.00      0.00      0.00         1
#
#         accuracy                           0.49       270
#        macro avg       0.11      0.12      0.11       270
#     weighted avg       0.35      0.49      0.39       270
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
location_pred = clf.predict(X_tfidf)
df["location_predicted"] = location_pred

df["location_mismatch"] = df["location_predicted"] != df["Location"]
df["is_suspicious"] = (df["anomaly_label"] == -1) | (df["location_mismatch"])

# %%
df[[
    "Heading", "location_extracted", "location_predicted",
    "anomaly_score", "is_suspicious"
]].head(10)
# Out:
#                                              Heading location_extracted  \
# 0  sindh govt decides to cut public transport far...            UNKNOWN
# 1                    asia stocks up in new year trad               asia
# 2           hong kong stocks open 0.66 percent lower          hong kong
# 3              asian stocks sink euro near nine year            UNKNOWN
# 4                 us oil prices slip below 50 a barr                 us
# 5        oil hits new 5.5 year lows as saudis defend            UNKNOWN
# 6  bullish kse jumps over 33000 psychological bar...            UNKNOWN
# 7                    oil falls further in asian trad            UNKNOWN
# 8              sugar prices drop to rs 49.80 in sind            UNKNOWN
# 9   oil extends losses as world bank cuts growth for            UNKNOWN
#
#   location_predicted  anomaly_score  is_suspicious
# 0           Pakistan      -0.033961           True
# 1               asia      -0.007987           True
# 2           Pakistan      -0.040761           True
# 3                 US      -0.005093           True
# 4                 US       0.002804           True
# 5                 US      -0.009039           True
# 6           Pakistan      -0.023379           True
# 7                 US      -0.009435           True
# 8           Pakistan      -0.033315           True
# 9                 US      -0.002587           True

# %%
import joblib

joblib.dump(tfidf, "vectorizer_tfidf.pkl")
joblib.dump(iso, "model_isolation_forest.pkl")
joblib.dump(clf, "model_location_classifier.pkl")

df.to_csv("news_with_flags.csv", index=False)
